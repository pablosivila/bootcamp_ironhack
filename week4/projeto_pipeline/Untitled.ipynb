# %%
import pandas as pd

# %%
jogadores = pd.read_csv("2014_jogadores.csv")

# %%
jogadores
# Out:
#          ID             Apelido  ClubeID  PosicaoID
# 0     80583          Lucas Lima      277          4
# 1     72079        Bruno Cortez      288          2
# 2     86189            Mosquito      293          5
# 3     68938    Giovanni Augusto      316          4
# 4     68974              Marcão      316          5
# 5     71799            Silvinho      288          5
# 6     63005            Welinton      294          3
# 7     37705                Juan      287          2
# 8     87399        Mário Sérgio      293          2
# 9     77579          Dellatorre      293          5
# 10    51683        Bruno Rangel      315          5
# 11    84382              Danilo      292          2
# 12    78850            Reinaldo      276          2
# 13    69008                Neto      277          3
# 14    37790               Ceará      283          2
# 15    78248    Gustavo Henrique      277          3
# 16    73855               Jubal      277          3
# ...

# %%
lances = pd.read_csv("2014_lances.csv")

# %%
lances
# Out:
#               ID  PartidaID  ClubeID  AtletaID Periodo  Momento Tipo
# 0      121677889     180064      263     38523     1tr      3.0   FC
# 1      121677887     180064      263     37621     1tr      2.0   FR
# 2      121677886     180064      263     37621     1tr      2.0   RB
# 3      121677884     180064      263     38523     1tr      2.0   FC
# 4      121677882     180064      263     37789     1tr      1.0   PE
# 5      121677880     180064      263     73540     1tr      1.0   FR
# 6      121737581     180064      263     38523     1tr     25.0   ZG
# 7      121737585     180064      263     38523     1tr     14.0   CA
# 8      121737584     180064      263     68744     2tr      3.0   CA
# 9      121677930     180064      263     69232     1tr     21.0   FC
# 10     121677936     180064      263     37652     1tr     23.0   IM
# 11     121677935     180064      263     38523     1tr     23.0   ZD
# 12     121677939     180064      263     37652     1tr     24.0   FR
# ...

# %%
partidas_id=pd.read_csv("2014_partidas_ids.csv")

# %%
partidas_id
# Out:
#          ID  Rodada  Casa  Visitante  PlacarCasa  PlacarVisitante  Resultado
# 0    179872       1   262        290           0                0     Empate
# 1    179873       1   266        316           3                0       Casa
# 2    179874       1   276        263           3                0       Casa
# 3    179875       1   277        292           1                1     Empate
# 4    179876       1   293        284           1                0       Casa
# 5    179877       1   282        264           0                0     Empate
# 6    179878       1   265        283           1                2  Visitante
# 7    179879       1   285        287           1                0       Casa
# 8    179880       1   288        275           1                2  Visitante
# 9    179881       1   315        294           0                0     Empate
# 10   179882       2   263        285           2                2     Empate
# ...

# %%
partidas=pd.read_csv("2014_partidas.csv")

# %%
partidas
# Out:
#      Unnamed: 0  game  round                date           home_team  score  \
# 0             1     1      1  20/04/2014 - 18:30       Flamengo - RJ  0 x 0
# 1             2     2      1  19/04/2014 - 18:30     Fluminense - RJ  3 x 0
# 2             3     3      1  20/04/2014 - 16:00      São Paulo - SP  3 x 0
# 3             4     4      1  20/04/2014 - 18:30         Santos - SP  1 x 1
# 4             5     5      1  20/04/2014 - 16:00       Atletico - PR  1 x 0
# 5             6     6      1  20/04/2014 - 16:00       Atlético - MG  0 x 0
# 6             7     7      1  20/04/2014 - 16:00          Bahia - BA  1 x 2
# 7             8     8      1  19/04/2014 - 18:30  Internacional - RS  1 x 0
# 8             9     9      1  20/04/2014 - 18:30       Criciuma - SC  1 x 2
# 9            10    10      1  19/04/2014 - 21:00    Chapecoense - SC  0 x 0
# 10           11    11      2  27/04/2014 - 16:00       Botafogo - RJ  2 x 2
# ...

# %%
scouts=pd.read_csv("2014_scouts_raw.csv")

# %%
scouts
# Out:
#        Atleta  Rodada  Clube  Participou  Posicao  Jogos  Pontos  PontosMedia  \
# 0       36443       0    NaN           0      NaN      0     0.0         0.00
# 1       36443       1  285.0           1      1.0      1     5.0         5.00
# 2       36443       2  285.0           1      1.0      2    -3.0         1.00
# 3       36443       3  285.0           1      1.0      3    -2.6        -0.20
# 4       36443       4  285.0           1      1.0      4     4.0         0.85
# 5       36443       5  285.0           1      1.0      5     5.0         1.68
# 6       36443       6  285.0           1      1.0      6     1.2         1.60
# 7       36443       7  285.0           1      1.0      7    -3.3         0.90
# 8       36443       8  285.0           1      1.0      8     3.0         1.16
# 9       36443       9  285.0           1      1.0      9    -1.5         0.86
# 10      36443      10  285.0           1      1.0     10    -4.0         0.37
# ...

# %%
times=pd.read_csv("2014_times.csv")

# %%
times
# Out:
#      ID           Nome Abreviacao           Slug
# 0   262       flamengo        FLA       flamengo
# 1   263       botafogo        BOT       botafogo
# 2   264    corinthians        COR    corinthians
# 3   265          bahia        BAH          bahia
# 4   266     fluminense        FLU     fluminense
# 5   275      palmeiras        PAL      palmeiras
# 6   276      são paulo        SAO      sao-paulo
# 7   277         santos        SAN         santos
# 8   282    atlético-mg        CAM    atletico-mg
# 9   283       cruzeiro        CRU       cruzeiro
# 10  284         grêmio        GRE         gremio
# 11  285  internacional        INT  internacional
# 12  287        vitória        VIT        vitoria
# 13  288       criciúma        CRI       criciuma
# 14  290          goiás        GOI          goias
# 15  292          sport        SPO          sport
# 16  293    atlético-pr        CAP    atletico-pr
# 17  294       coritiba        CFC       coritiba
# ...

# %%
tabela2017=pd.read_csv("2017_tabela.csv")

# %%
tabela2017
# Out:
#     Pos               Clube   P   J   V   E   D  GP  GC  SG  VM  VV  DM  DV  \
# 0    1º    Corinthians - SP  72  38  21   9   8  50  30  20  12   9   2   6
# 1    2º      Palmeiras - SP  63  38  19   6  13  61  45  16  12   7   4   9
# 2    3º         Santos - SP  63  38  17  12   9  42  32  10  12   5   3   6
# 3    4º         Grêmio - RS  62  38  18   8  12  55  36  19  10   8   5   7
# 4    5º       Cruzeiro - MG  57  38  15  12  11  47  39   8   9   6   3   8
# 5    6º       Flamengo - RJ  56  38  15  11  12  49  38  11  10   5   3   9
# 6    7º  Vasco da Gama - RJ  56  38  15  11  12  40  47  -7   8   7   4   8
# 7    8º    Chapecoense - SC  54  38  15   9  14  47  49  -2   9   6   7   7
# 8    9º       Atlético - MG  54  38  14  12  12  52  49   3   7   7   8   4
# 9   10º       Botafogo - RJ  53  38  14  11  13  45  42   3   9   5   7   6
# 10  11º       Atlético - PR  51  38  14   9  15  45  43   2   8   6   6   9
# ...

# %%
agregados2017=pd.read_csv("dados_agregados_limpos.csv")

# %%
agregados2017
# Out:
#          A             Apelido  AtletaID   CA   CV        ClubeID   DD   DP  \
# 0      0.0                Juan     36540  1.0  0.0  Internacional  0.0  0.0
# 1      0.0                Juan     36540  0.0  0.0  Internacional  0.0  0.0
# 2      0.0                Juan     36540  1.0  0.0  Internacional  0.0  0.0
# 3      0.0                Juan     36540  0.0  0.0  Internacional  0.0  0.0
# 4      0.0                Juan     36540  1.0  0.0  Internacional  0.0  0.0
# 5      0.0                Juan     36540  0.0  0.0  Internacional  0.0  0.0
# 6      0.0                Juan     36540  0.0  0.0  Internacional  0.0  0.0
# 7      0.0                Juan     36540  0.0  0.0  Internacional  0.0  0.0
# 8      0.0                Juan     36540  0.0  0.0  Internacional  0.0  0.0
# 9      1.0                Juan     36540  0.0  0.0  Internacional  0.0  0.0
# 10     0.0                Juan     36540  1.0  0.0  Internacional  0.0  0.0
# ...

# %%
agregados2017.columns
# Out:
# Index(['A', 'Apelido', 'AtletaID', 'CA', 'CV', 'ClubeID', 'DD', 'DP', 'FC',
#        'FD', 'FF', 'FS', 'FT', 'G', 'GC', 'GS', 'I', 'Jogos', 'PE', 'PP',
#        'Participou', 'Pontos', 'PontosMedia', 'Posicao', 'Preco',
#        'PrecoVariacao', 'RB', 'Rodada', 'SG', 'Status', 'ano', 'avg.A',
#        'avg.A.l05', 'avg.CA', 'avg.CV.l05', 'avg.DD', 'avg.DD.l05', 'avg.DP',
#        'avg.DP.l05', 'avg.FC', 'avg.FC.l05', 'avg.FD', 'avg.FD.l05', 'avg.FF',
#        'avg.FF.l05', 'avg.FS', 'avg.FS.l05', 'avg.FT', 'avg.FT.l05', 'avg.G',
#        'avg.G.l05', 'avg.GC', 'avg.GC.l05', 'avg.GS', 'avg.GS.l05', 'avg.I',
#        'avg.I.l05', 'avg.PE', 'avg.PE.l05', 'avg.PP', 'avg.PP.l05',
#        'avg.Points', 'avg.RB', 'avg.RB.l05', 'avg.SG', 'avg.SG.l05',
#        'avg.last05', 'away.score.x', 'dia', 'home.attack', 'home.defend',
#        'home.score.x', 'mes', 'pred.away.score', 'pred.home.score',
#        'risk_points', 'variable'],
#       dtype='object')

# %%
agregados2017['Posicao'].value_counts()
# Out:
# mei    6516
# ata    4050
# lat    3045
# zag    2628
# gol    1328
# Name: Posicao, dtype: int64

# %%
#verificando os dados de 2018:
tabela2018=pd.read_csv("2018_tabelas.csv") #não usar - desatualizada

# %%
tabela2018
# Out:
#     Pos               Clube   P  J  V  E  D  GP  GC  SG  VM  VV  DM  DV  CA  \
# 0    1º       Flamengo - RJ  10  5  3  1  1  11   5   6   2   1   0   1  13
# 1    2º    Corinthians - SP  10  5  3  1  1   8   3   5   2   1   0   1   8
# 2    3º       Atlético - MG  10  5  3  1  1   8   6   2   2   1   0   1  15
# 3    4º         Grêmio - RS   8  5  2  2  1   7   3   4   1   1   0   1   9
# 4    5º      Palmeiras - SP   8  5  2  2  1   5   3   2   1   1   0   1  15
# 5    6º       Botafogo - RJ   8  5  2  2  1   6   5   1   2   0   0   1  11
# 6    7º  Vasco da Gama - RJ   7  4  2  1  1   9   6   3   2   0   1   0  12
# 7    8º       Cruzeiro - MG   7  5  2  1  2   3   2   1   2   0   1   1  11
# 8    9º     Fluminense - RJ   7  5  2  1  2   6   6   0   1   1   0   2   9
# 9   10º        América - MG   7  5  2  1  2   8   9  -1   2   0   0   2  10
# 10  11º          Sport - PE   7  5  2  1  2   5   7  -2   1   1   0   2   9
# ...

# %%
jogadores2018=pd.read_csv("2018_jogadores.csv")

# %%
jogadores2018
# Out:
#      atletas.atleta_id    atletas.apelido atletas.clube.id.full.name  \
# 0                37717  Fernando Henrique                      Ceará
# 1                37657        Edu Dracena                  Palmeiras
# 2                36540               Juan                   Flamengo
# 3                37281       Mano Menezes                   Cruzeiro
# 4                37306      Gilson Kleina                Chapecoense
# 5                37674             Wagner                      Vasco
# 6                37656              Fábio                   Cruzeiro
# 7                37604        Paulo André                Atlético-PR
# 8                37607      Michel Bastos                      Sport
# 9                37688             Cícero                     Grêmio
# 10               37662           Jonathan                Atlético-PR
# 11               37655       Rafael Moura                 América-MG
# 12               60969             Patric                Atlético-MG
# ...
